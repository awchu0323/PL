# %%
import pandas as pd

# read csv file

horse = pd.read_csv("賽程表 1.csv")

# %%
horse.tail()
# Out:
#     Unnamed: 0   年數    月 前後    競賽名稱  階級    距離   分類  跑道  場地 行進方向  粉絲増加（人）
# 371        資深級  第３年  12月  後    有馬紀念  G1  2500  長距離  草地  中山  順・内    30000
# 372        資深級  第３年  12月  後   東京大賞典  G1  2000  中距離  沙地  大井    順     8000
# 373        資深級  第３年  12月  後     阪神盃  G2  1400  短距離  草地  阪神  順・内     6700
# 374        資深級  第３年  12月  後   銀河錦標賽  OP  1400  短距離  沙地  阪神    順     2200
# 375        資深級  第３年  12月  後  參宿四錦標賽  OP  1800   一哩  沙地  阪神    順     2200
