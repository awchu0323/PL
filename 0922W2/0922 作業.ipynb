# %%
import pandas as pd

# read csv file

dis = pd.read_csv("race distance.csv")
gro = pd.read_csv("race ground.csv")

# %%
dis.tail()
# Out:
#     Unnamed: 0   年數    月 前後    競賽名稱  階級   分類
# 371        資深級  第３年  12月  後    有馬紀念  G1  長距離
# 372        資深級  第３年  12月  後   東京大賞典  G1  中距離
# 373        資深級  第３年  12月  後     阪神盃  G2  短距離
# 374        資深級  第３年  12月  後   銀河錦標賽  OP  短距離
# 375        資深級  第３年  12月  後  參宿四錦標賽  OP   一哩

# %%
gro.tail()
# Out:
#     Unnamed: 0   年數    月 前後    競賽名稱  階級  跑道
# 371        資深級  第３年  12月  後    有馬紀念  G1  草地
# 372        資深級  第３年  12月  後   東京大賞典  G1  沙地
# 373        資深級  第３年  12月  後     阪神盃  G2  草地
# 374        資深級  第３年  12月  後   銀河錦標賽  OP  沙地
# 375        資深級  第３年  12月  後  參宿四錦標賽  OP  沙地

# %%
s_dis = set( dis ["階級"] )
s_gro = set( gro ["階級"] )

# %%
s_dis|s_gro
# Out:
# {'G1', 'G2', 'G3', 'OP', 'Pre-OP'}
