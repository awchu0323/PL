# %%
import pandas as pd

# read csv file

horse = pd.read_csv("賽程表1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       1 import pandas as pd
#       3 # read csv file
# ----> 5 horse = pd.read_csv("賽程表1.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
horse.tail()
# Out:
#     Unnamed: 0   年數    月 前後    競賽名稱  階級    距離   分類  跑道  場地  ... Unnamed: 22  \
# 371        資深級  第３年  12月  後    有馬紀念  G1  2500  長距離  草地  中山  ...          重砲
# 372        資深級  第３年  12月  後   東京大賞典  G1  2000  中距離  沙地  大井  ...         NaN
# 373        資深級  第３年  12月  後     阪神盃  G2  1400  短距離  草地  阪神  ...         NaN
# 374        資深級  第３年  12月  後   銀河錦標賽  OP  1400  短距離  沙地  阪神  ...         NaN
# 375        資深級  第３年  12月  後  參宿四錦標賽  OP  1800   一哩  沙地  阪神  ...         NaN
#
#      Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 371         超級小溪        目白雷恩        愛麗速子        勝利獎券        春烏拉拉        待兼福來
# 372          NaN         NaN         NaN         NaN         NaN         NaN
# 373          NaN         NaN         NaN         NaN         NaN         NaN
# 374          NaN         NaN         NaN         NaN         NaN         NaN
# 375          NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 29 Unnamed: 30 Unnamed: 31
# ...
