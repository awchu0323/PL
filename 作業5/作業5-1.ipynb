# %%
import jieba
import jieba.analyse
import pandas as pd
import numpy as np
from collections import Counter

# %%
import pandas as pd
from collections import Counter

# %%
data1 = pd.read_csv('臺北市街頭隨機搶奪案件點位資訊.csv')
data1
# Out:
#     編號  案類     發生日期   發生時段                       發生地點  備註
# 0    1  搶奪  1070209  02~04            台北市中山區新生北路3段56巷 NaN
# 1    2  搶奪  1070313  18~20   台北市北投區關渡里知行路316巷22弄1~30號 NaN
# 2    3  搶奪  1070316  18~20          台北市中正區富水里思源街與永春街口 NaN
# 3    4  搶奪  1070519  00~02            台北市萬華區(桂林路與柳州街) NaN
# 4    5  搶奪  1070611  18~20      台北市北投區八仙里西安街2段(與公館路口) NaN
# 5    6  搶奪  1070706  00~02         台北市中山區林森北路511~540號 NaN
# 6    7  搶奪  1070730  20~22             台北市內湖區康樂街1~30號 NaN
# 7    8  搶奪  1071118  04~06       台北市士林區福佳里中正路211~240號 NaN
# 8    9  搶奪  1071227  12~14          台北市大同區伊寧街75巷(伊寧街) NaN
# 9   10  搶奪  1080118  12~14      台北市中正區三愛里臨沂街59巷31~60號 NaN
# 10  11  搶奪  1080118  20~22           台北市萬華區環河南路2段5巷口巷 NaN
# 11  12  搶奪  1080327  18~20        台北市中正區網溪里廈門街123巷(內) NaN
# 12  13  搶奪  1080327  20~22         台北市中正區河堤里同安街紀州庵前2段 NaN
# 13  14  搶奪  1080430  18~20             台北市萬華區成都路76巷口弄 NaN
# 14  15  搶奪  1080802  16~18           台北市萬華區(華西街與桂林路口) NaN
# 15  16  搶奪  1080807  06~08            台北市大同區哈密街59巷21弄 NaN
# 16  17  搶奪  1080826  16~18      台北市信義區四維里虎林街70巷31~60號 NaN
# 17  18  搶奪  1081205  18~20            台北市萬華區漢中街31~60號 NaN
# 18  19  搶奪  1090210  22~24        台北市萬華區武昌街2段121~150號 NaN
# 19  20  搶奪  1090216  12~14          台北市萬華區昆明街181~210號 NaN
# 20  21  搶奪  1090223  22~24    台北市文山區景行里羅斯福路6段391~420號 NaN
# 21  22  搶奪  1090416  14~16         台北市大同區迪化街1段(永樂市場2號 NaN
# 22  23  搶奪  1090422  00~02        台北市大安區龍安里和平東路1段199巷 NaN
# 23  24  搶奪  1090822  14~16          台北市中山區中山北路2段與錦西街口 NaN
# 24  25  搶奪  1090927  00~02             台北市萬華區梧州街與廣州街口 NaN
# 25  26  搶奪  1091106  16~18       台北市大同區延平北路2段151~180號 NaN
# 26  27  搶奪  1091124  18~20            台北市萬華區梧州街31~60號 NaN
# 27  28  搶奪  1100328  22~24           台北市中山區建國北路三段75巷內 NaN
# 28  29  搶奪  1100504  18~20  台北市士林區福安里延平北路7段107巷31~60號 NaN
# 29  30  搶奪  1100617  10~12      台北市大同區延平北路2段247巷1~30號 NaN
# 30  31  搶奪  1100627  16~18    台北市北投區中和里中和街441巷3弄1~30號 NaN
# 31  32  搶奪  1100924  04~60       台北市大同區長安西路78巷4弄1~30號 NaN
# 32  33  搶奪  1110328  20~22            台北市南港區新民街61~90號 NaN
# 33  34  搶奪  1110331  10~12        台北市大同區環河北路2段91~120號 NaN
# 34  35  搶奪  1110625  00-01         台北市南港區南港路3段91~120巷 NaN

# %%
data1['seg'] = ""
data1['seg1'] = ""
data1.head()
# Out:
#    編號  案類     發生日期   發生時段                      發生地點  備註 seg seg1
# 0   1  搶奪  1070209  02~04           台北市中山區新生北路3段56巷 NaN
# 1   2  搶奪  1070313  18~20  台北市北投區關渡里知行路316巷22弄1~30號 NaN
# 2   3  搶奪  1070316  18~20         台北市中正區富水里思源街與永春街口 NaN
# 3   4  搶奪  1070519  00~02           台北市萬華區(桂林路與柳州街) NaN
# 4   5  搶奪  1070611  18~20     台北市北投區八仙里西安街2段(與公館路口) NaN

# %%
index = 0
for documents in data1['發生時段']:
    seg_list = jieba.analyse.extract_tags(documents, 150)
    data1['seg'].iloc[index] = seg_list
    index += 1
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_16892\2059048071.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['seg'].iloc[index] = seg_list

# %%
data1["seg"]
# Out:
# 0     [02, 04]
# 1     [18, 20]
# 2     [18, 20]
# 3     [00, 02]
# 4     [18, 20]
# 5     [00, 02]
# 6     [20, 22]
# 7     [04, 06]
# 8     [12, 14]
# 9     [12, 14]
# 10    [20, 22]
# 11    [18, 20]
# 12    [20, 22]
# 13    [18, 20]
# 14    [16, 18]
# 15    [06, 08]
# 16    [16, 18]
# 17    [18, 20]
# 18    [22, 24]
# 19    [12, 14]
# 20    [22, 24]
# 21    [14, 16]
# 22    [00, 02]
# 23    [14, 16]
# 24    [00, 02]
# 25    [16, 18]
# 26    [18, 20]
# 27    [22, 24]
# 28    [18, 20]
# 29    [10, 12]
# 30    [16, 18]
# 31    [04, 60]
# 32    [20, 22]
# 33    [10, 12]
# 34    [00, 01]
# Name: seg, dtype: object

# %%
index = 0
for documents in data1['發生地點']:
    seg_list = jieba.analyse.extract_tags(documents, 150)
    data1['seg1'].iloc[index] = seg_list
    index += 1
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_16892\3375688981.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['seg1'].iloc[index] = seg_list

# %%
data1["seg1"]
# Out:
# 0                     [新生北路, 56, 台北市, 中山]
# 1     [區關, 渡里知, 316, 22, 30, 北投, 行路, 台北市]
# 2               [永春, 富水, 中正, 台北市, 街口, 思源]
# 3                      [萬華區, 台北市, 柳州, 桂林]
# 4               [公館, 北投, 八仙, 台北市, 路口, 西安]
# 5               [林森北路, 511, 540, 台北市, 中山]
# 6                      [湖區, 康樂街, 30, 台北市]
# 7          [區福佳里, 中正路, 211, 240, 台北市, 士林]
# 8                [區伊寧街, 75, 伊寧街, 台北市, 大同]
# 9        [區三愛里, 臨沂街, 59, 31, 60, 中正, 台北市]
# 10                    [萬華區環, 台北市, 巷口, 河南]
# 11             [區網, 溪里, 廈門, 123, 中正, 台北市]
# 12                 [街紀州, 同安, 中正, 台北市, 河堤]
# 13                [成都路, 萬華區, 76, 台北市, 巷口]
# 14                 [萬華區, 台北市, 西街, 桂林, 路口]
# 15                  [59, 21, 台北市, 哈密, 大同]
# 16        [信義區, 四維里, 70, 31, 60, 虎林, 台北市]
# 17                 [萬華區, 31, 60, 台北市, 中街]
# 27       [區建國, 75, 巷內, 三段, 台北市, 北路, 中山]
# 28     [延平北路, 107, 31, 60, 福安, 台北市, 士林]
# 29             [延平北路, 247, 30, 台北市, 大同]
# 30               [區中, 441, 30, 北投, 台北市]
# 31            [區長, 78, 30, 台北市, 安西, 大同]
# 32                [61, 90, 南港, 台北市, 新民]
# 33           [區環, 91, 120, 台北市, 大同, 河北]
# 34              [南港路, 91, 120, 南港, 台北市]

# %%
output_series = crimedata.groupby(['發生時段'])['seg'].apply(lambda x: ','.join(x)).reset_index()
output_series
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1414, in GroupBy.apply(self, func, *args, **kwargs)
#    1413 try:
# -> 1414     result = self._python_apply_general(f, self._selected_obj)
#    1415 except TypeError:
#    1416     # gh-20949
#    1417     # try again, with .apply acting as a filtering
#    (...)
#    1421     # fails on *some* columns, e.g. a numeric operation
#    1422     # on a string grouper column
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1455, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1436 """
#    1437 Apply function f in python space
#    1438
#    (...)
#    1453     data after applying f
#    1454 """
# -> 1455 values, mutated = self.grouper.apply(f, data, self.axis)
#    1457 if not_indexed_same is None:
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:761, in BaseGrouper.apply(self, f, data, axis)
#     760 group_axes = group.axes
# --> 761 res = f(group)
#     762 if not mutated and not _is_indexed_like(res, group_axes, axis):
#
# Input In [27], in <lambda>(x)
# ----> 1 output_series = crimedata.groupby(['發生時段'])['seg'].apply(lambda x: ','.join(x)).reset_index()
#       2 output_series
#
# TypeError: sequence item 0: expected str instance, list found
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 output_series = crimedata.groupby(['發生時段'])['seg'].apply(lambda x: ','.join(x)).reset_index()
#       2 output_series
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:244, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     238 @Appender(
#     239     _apply_docs["template"].format(
#     240         input="series", examples=_apply_docs["series_examples"]
#     241     )
#     242 )
#     243 def apply(self, func, *args, **kwargs):
# --> 244     return super().apply(func, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1425, in GroupBy.apply(self, func, *args, **kwargs)
#    1415     except TypeError:
#    1416         # gh-20949
#    1417         # try again, with .apply acting as a filtering
#    (...)
#    1421         # fails on *some* columns, e.g. a numeric operation
#    1422         # on a string grouper column
#    1424         with self._group_selection_context():
# -> 1425             return self._python_apply_general(f, self._selected_obj)
#    1427 return result
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1455, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1429 @final
#    1430 def _python_apply_general(
#    1431     self,
#    (...)
#    1434     not_indexed_same: bool | None = None,
#    1435 ) -> DataFrame | Series:
#    1436     """
#    1437     Apply function f in python space
#    1438
#    (...)
#    1453         data after applying f
#    1454     """
# -> 1455     values, mutated = self.grouper.apply(f, data, self.axis)
#    1457     if not_indexed_same is None:
#    1458         not_indexed_same = mutated or self.mutated
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:761, in BaseGrouper.apply(self, f, data, axis)
#     759 # group might be modified
#     760 group_axes = group.axes
# --> 761 res = f(group)
#     762 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763     mutated = True
#
# Input In [27], in <lambda>(x)
# ----> 1 output_series = crimedata.groupby(['發生時段'])['seg'].apply(lambda x: ','.join(x)).reset_index()
#       2 output_series
#
# TypeError: sequence item 0: expected str instance, list found
